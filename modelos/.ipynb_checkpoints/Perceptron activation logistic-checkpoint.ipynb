# %% [markdown]
# # Perceptron - solucion con logistic
#
# El modelo biológico más simple de un perceptrón es una neurona y viceversa. Es decir, el modelo matemático más simple de una neurona es un perceptrón. La neurona es una célula especializada y caracterizada por poseer una cantidad indefinida de canales de entrada llamados dendritas y un canal de salida llamado axón. Las dendritas operan como sensores que recogen información de la región donde se hallan y la derivan hacia el cuerpo de la neurona que reacciona mediante una sinapsis que envía una respuesta hacia el cerebro.
#
# Una neurona sola y aislada carece de razón de ser. Su labor especializada se torna valiosa en la medida en que se asocia a otras neuronas, formando una red. Normalmente, el axón de una neurona entrega su información como «señal de entrada» a una dendrita de otra neurona y así sucesivamente. El perceptrón que capta la señal en adelante se extiende formando una red de neuronas, sean éstas biológicas o de sustrato semiconductor (compuertas lógicas).
#
# link: https://es.wikipedia.org/wiki/Perceptr%C3%B3n
#
# <img src="https://media.licdn.com/dms/image/v2/C4E12AQEXnAjON3lahQ/article-cover_image-shrink_600_2000/article-cover_image-shrink_600_2000/0/1624840552254?e=2147483647&v=beta&t=idlwgxZEL44s-zyrXWyxbPJmtSjxal7h-d_p0R9gIkg"/>

# %%
from sklearn.datasets import make_blobs

import matplotlib.pyplot as plt
import numpy as np

# %%
DATA_POINTS = 1000
ITERATIONS = 200

# %% [markdown]
# ## Generar data

# %%
# Generamos 2 clusters, con 300 puntos en total
X, y = make_blobs(n_samples=DATA_POINTS, centers=2, cluster_std=1.0, random_state=12)

# dato adicional
nuevo_punto = np.array([[-6, 1.5]])
nueva_etiqueta = np.array([0])
#X = np.vstack((X, nuevo_punto))
#y = np.append(y, nueva_etiqueta)

# X contiene los puntos (x, y), y es la etiqueta del cluster
plt.scatter(X[:, 0], X[:, 1], c=y, cmap='viridis')
plt.xlabel("x")
plt.ylabel("y")
plt.title("Clusters generados")
plt.show()

# %%
print( "formato de X: " , X.shape )
print( "ejemplo de X: " , X[0:5] )
# Out:
# formato de X:  (1000, 2)
# ejemplo de X:  [[-4.82009419  0.31265986]
#  [-4.85798902 -0.75532612]
#  [-5.87148063  0.18708564]
#  [-7.11190461  3.67526298]
#  [-7.76416753  5.85370709]]

# %%
print( "formato de y: " , y.shape )
print( "ejemplo de y: " , y[0:5] )
# Out:
# formato de y:  (1000,)
# ejemplo de y:  [1 1 1 0 0]

# %% [markdown]
# ## Algoritmo

# %%
def function_activation_step(x):
    return 1 if x>=0 else 0

# %%
def perceptron_f_step(data_x, data_y, max_iterations=100, learning_rate=0.1):

    errors_history = []
    
    data = np.insert(data_x, 0, 1, axis=1)  # Agrega columna bias, inserta values en arr en la posición index, a lo largo del axis que indiques.
    W = np.zeros(data.shape[1])            # Pesos, incluyendo bias

    for iteracion in range(max_iterations):
        
        errores_totales = 0
        
        for i in range(len(data)):
            resultado = np.dot( W , data[i])
            prediccion = function_activation_step(resultado)
            error = data_y[i] - prediccion

            if error != 0:
                # Ajustar pesos
                W += learning_rate * error * data[i]
                errores_totales += 1

        errors_history.append(errores_totales)
        
        #print(f"iteracion({iteracion}) -> {errores_totales} errores")
        if errores_totales == 0:
            break  # Ya clasificó correctamente todo

    return W, errors_history

# %%
W, step_errors = perceptron_f_step(X,y, max_iterations= ITERATIONS)

x_min = np.min(X[:, 0])
x_max = np.max(X[:, 0])
y_min = np.min(X[:, 1])
y_max = np.max(X[:, 1])

model_plot_x_range = np.linspace(x_min,x_max,100)

w0 = W[0]
w1 = W[1]
w2 = W[2]

predicciones = -(w1 / w2) * model_plot_x_range - (w0 / w2)

plt.plot( model_plot_x_range, predicciones )
plt.scatter(X[:, 0], X[:, 1], c=y, cmap='viridis')
plt.xlabel("x")
plt.ylabel("y")
plt.title(f"W: {W}")
plt.xlim(x_min-1,x_max+1)
plt.ylim(y_min-1,y_max+1)
plt.show()

# %% [markdown]
# ## Aplicar una funcion de activacion diferente
#
# <img src="https://scontent.fbog4-1.fna.fbcdn.net/v/t1.6435-9/86369425_2797277730499305_7539190797451657216_n.jpg?stp=dst-jpg_p526x296_tt6&_nc_cat=101&ccb=1-7&_nc_sid=536f4a&_nc_ohc=PSZ6wOcnLQ0Q7kNvwFF-Uny&_nc_oc=AdnV4dfnW03h-LZj6SDs-C3-1w2TDVDPODeCN46UNjbyNiS2NrKh_QPSZ6M9b9zrFAk&_nc_zt=23&_nc_ht=scontent.fbog4-1.fna&_nc_gid=Zwj-KfoEVqLF3NHbQXatow&oh=00_AfH8xfXUAg_HQpPxNeL57BIIq9DPco2HYa90hzGz9EVdYw&oe=681A76E0">

# %%
import math

def function_activation_logistic(x):
    return 1 / (1 + math.e**(-1*x) )

# %%
def perceptron_f_logistic(data_x, data_y, max_iterations=100, learning_rate=0.1):
    errors_history = []
    data = np.insert(data_x, 0, 1, axis=1)  # Agregar bias
    W = np.zeros(data.shape[1])  # Inicializar pesos

    for iteracion in range(max_iterations):
        error_acumulado = 0
        
        for i in range(len(data)):
            # Calcular predicción y error
            resultado = np.dot(W, data[i])
            prediccion = function_activation_logistic(resultado)
            error = data_y[i] - prediccion  # Error para gradiente
            
            # Actualizar pesos
            W += learning_rate * error * data[i]

            error_acumulado += error ** 2
        
        errors_history.append(error_acumulado)
        
    return W, errors_history

# %%
W, logistic_errors = perceptron_f_logistic(X,y, max_iterations= ITERATIONS)

x_min = np.min(X[:, 0])
x_max = np.max(X[:, 0])
y_min = np.min(X[:, 1])
y_max = np.max(X[:, 1])

model_plot_x_range = np.linspace(x_min,x_max,100)

w0 = W[0]
w1 = W[1]
w2 = W[2]

predicciones = -(w1 / w2) * model_plot_x_range - (w0 / w2)

plt.plot( model_plot_x_range, predicciones )
plt.scatter(X[:, 0], X[:, 1], c=y, cmap='viridis')
plt.xlabel("x")
plt.ylabel("y")
plt.title(f"W: {W}")
plt.xlim(x_min-1,x_max+1)
plt.ylim(y_min-1,y_max+1)
plt.show()

# %% [markdown]
# ## Error evolution

# %%
plt.plot( range(0,len(step_errors)) , step_errors, label="function step" )
plt.plot( range(0,len(logistic_errors)) , logistic_errors, label="function logistic" )
plt.legend()
